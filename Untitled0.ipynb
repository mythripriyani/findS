# %%
import csv
a = []
with open('pll-team-stats.csv', 'r') as csvfile:
   for row in csv.reader(csvfile):
      a.append(row)
print(a)
print("\n The total number of training instances are : ",len(a))
num_attribute = len(a[0])-1
print("\n The initial hypothesis is : ")
hypothesis = ['0']*num_attribute
print(hypothesis)
for i in range(0, len(a)):
  if a[i][num_attribute] == 'yes':
    for j in range(0, num_attribute):
      if hypothesis[j] == '0' or hypothesis[j] == a[i][j]:
        hypothesis[j] = a[i][j]
      else:
        hypothesis[j] = '?'
print("\n The hypothesis for the training instance {} is :\n" .format(i+1),hypothesis)
print("\n The Maximally specific hypothesis for the training instance is ")
print(hypothesis)
# Out:
# [['season', 'team', 'wins', 'losses', 'scores_for', 'scores_against', 'score_differential', 'one_point_goals', 'two_point_goals', 'assists', 'shots', 'shot_percentage', 'x2_point_shots', 'x2_point_shot_pecentage', 'shots_on_goal', 'shots_on_goal_pecentage', 'turnovers', 'caused_turnovers', 'groundballs', 'faceoff_pecentage', 'faceoffs_won', 'faceoffs_lost', 'saves', 'save_percentage', 'penalties', 'penalty_minutes', 'power_play_pecentage', 'power_play_goals', 'power_play_shots', 'x2_point_goals_allowed', 'penalty_kill_pecentage', 'penalty_kills', 'playoff_notes'], ['2019', 'Chaos', '7', '3', '130', '128', '2', '106', '12', '67', '382', '0.31', '57', '0.211', '234', '0.613', '144', '63', '272', '0.473', '133', '148', '156', '0.555', '33', '18', '0.478', '11', '8', '3', '0.69', '20 - 29', 'Lost Semifinals'], ['2019', 'Whipsnakes', '6', '4', '125', '116', '9', '101', '12', '71', '442', '0.26', '62', '0.194', '246', '0.557', '97', '54', '262', '0.521', '134', '123', '133', '0.55', '24', '13', '0.263', '5', '7', '7', '0.636', '14 - 22', 'Won Final'], ['2019', 'Atlas', '5', '5', '125', '132', '-7', '109', '8', '73', '402', '0.29', '64', '0.125', '248', '0.617', '124', '50', '286', '0.616', '167', '104', '140', '0.534', '42', '27', '0.435', '10', '9', '10', '0.7', '21 - 30', 'Lost Quarterfinals'], ['2019', 'Redwoods', '5', '5', '116', '117', '-1', '112', '2', '61', '435', '0.26', '42', '0.048', '252', '0.579', '122', '65', '256', '0.419', '106', '147', '117', '0.522', '19', '28', '0.353', '12', '20', '10', '0.643', '9 - 14', 'Lost Final'], ['2019', 'Archers', '5', '5', '112', '106', '6', '100', '6', '67', '438', '0.24', '42', '0.143', '257', '0.587', '130', '54', '266', '0.457', '111', '132', '126', '0.555', '24', '16', '0.519', '14', '9', '5', '0.714', '15 - 21', 'Missed Playoffs'], ['2019', 'Chrome', '2', '8', '127',